# %% [markdown]
# # T-test

# %% [markdown]
# A t-test is a type of inferential statistic which is used to determine if there is a significant difference between the means of two groups which may be related in certain features
#
# T-test has 2 types : 1. one sampled t-test 2. two-sampled t-test.

# %% [markdown]
# ### One-sample T-test with Python

# %% [markdown]
# The test will tell us whether means of the sample and the population are different

# %%
from IPython.display import Image
Image(filename='T-test Formula.png')

# %%
ages=[10,20,35,50,28,40,55,18,16,55,30,25,43,18,30,28,14,24,16,17,32,35,26,27,65,18,43,23,21,20,19,70]

# %%
len(ages)
# Out:
# 32

# %%
import numpy as np
np.mean(ages)
# Out:
# 30.34375

# %%
sample_size=10
age_sample=np.random.choice(ages,sample_size)

# %%
age_sample
# Out:
# array([16, 10, 32, 65, 27, 65, 30, 43, 30, 16])

# %%
from scipy.stats import ttest_1samp

# %%
t_test,p_value=ttest_1samp(age_sample,30)

# %%
p_value
# Out:
# 0.5886352482191993

# %%
if p_value < 0.05:    # alpha value is 0.05 or 5%
    print(" we are rejecting null hypothesis")
else:
    print("we are accepting null hypothesis")
# Out:
# we are accepting null hypothesis

# %% [markdown]
# ### Some More Examples
# Consider the age of students in a college and in Class A

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import math
np.random.seed(6)
school_ages=stats.poisson.rvs(loc=18,mu=35,size=1500)
classA_ages=stats.poisson.rvs(loc=18,mu=30,size=60)

# %%
classA_ages.mean()
# Out:
# 46.9

# %%
_,p_value=ttest_1samp(classA_ages,school_ages.mean())

# %%
p_value
# Out:
# 1.139027071016194e-13

# %%
if p_value < 0.05:    # alpha value is 0.05 or 5%
    print(" we are rejecting null hypothesis")
else:
    print("we are accepting null hypothesis")
# Out:
#  we are rejecting null hypothesis

# %%
school_ages.mean()
# Out:
# 53.303333333333335

# %% [markdown]
# # Two-sample T-test With Python

# %% [markdown]
# The Independent Samples t Test or 2-sample t-test compares the means of two independent groups in order to determine whether there is statistical evidence that the associated population means are significantly different. The Independent Samples t Test is a parametric test. This test is also known as: Independent t Test

# %%
from IPython.display import Image
Image(filename='T-test_two_side_formula.png')

# %%
np.random.seed(30)
ClassB_ages=stats.poisson.rvs(loc=18,mu=33,size=60)
ClassB_ages.mean()
# Out:
# 50.266666666666666

# %%
_,p_value=stats.ttest_ind(classA_ages,ClassB_ages,equal_var=False)

# %%
p_value
# Out:
# 0.001016747835759404

# %%
if p_value < 0.05:    # alpha value is 0.05 or 5%
    print(" we are rejecting null hypothesis")
else:
    print("we are accepting null hypothesis")
# Out:
#  we are rejecting null hypothesis

# %% [markdown]
# # Paired T-test With Python

# %% [markdown]
# When you want to check how different samples from the same group are, you can go for a paired T-test

# %%
weight1=[25,30,28,35,28,34,26,29,30,26,28,32,31,30,45]
weight2=weight1+stats.norm.rvs(scale=5,loc=-1.25,size=15)

# %%
print(weight1)
print(weight2)
# Out:
# [25, 30, 28, 35, 28, 34, 26, 29, 30, 26, 28, 32, 31, 30, 45]
# [21.70161087 31.63690364 28.83289988 36.35725863 19.38171758 29.76401755
#  39.85247976 26.11946417 25.88984423 20.67511419 29.74822142 28.88683424
#  31.9384869  31.32053988 47.54096785]

# %%
weight_pd=pd.DataFrame({"weight1":np.array(weight1),"weight2":np.array(weight2),"diff_weights":np.array(weight1)-np.array(weight2)})

# %%
weight_pd
# Out:
#     weight1    weight2  diff_weights
# 0        25  21.701611      3.298389
# 1        30  31.636904     -1.636904
# 2        28  28.832900     -0.832900
# 3        35  36.357259     -1.357259
# 4        28  19.381718      8.618282
# 5        34  29.764018      4.235982
# 6        26  39.852480    -13.852480
# 7        29  26.119464      2.880536
# 8        30  25.889844      4.110156
# 9        26  20.675114      5.324886
# 10       28  29.748221     -1.748221
# 11       32  28.886834      3.113166
# 12       31  31.938487     -0.938487
# 13       30  31.320540     -1.320540
# 14       45  47.540968     -2.540968

# %%
_,p_value=stats.ttest_rel(weight1,weight2)

# %%
p_value
# Out:
# 0.718119870190923

# %%
if p_value < 0.05:    # alpha value is 0.05 or 5%
    print(" we are rejecting null hypothesis")
else:
    print("we are accepting null hypothesis")
# Out:
# we are accepting null hypothesis
